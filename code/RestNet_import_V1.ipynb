# %%
# !pip install "torch==1.4" "torchvision==0.5.0"
# Out:
# ...
#      |████████████████████████████████| 753.4MB 23kB/s
# ...
#      |████████████████████████████████| 4.0MB 16.3MB/s
# ...
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.4.0 which is incompatible.
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# ...

# %%
from fastai import *
from fastai.vision import *

# %%
model_inf = load_learner('/Modelos_Resnet/')

# %%
ruta= "/IMG_20201022_165947.jpg"
img = open_image(ruta)
print(model_inf.predict(img)[0])
img
# Out:
# Malo
# Image (3, 480, 640)

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# arviz                         0.11.2
# astor                         0.8.1
# astropy                       4.2.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.3.0
# blis                          0.4.1
# bokeh                         2.3.2
# Bottleneck                    1.3.2
# ...
